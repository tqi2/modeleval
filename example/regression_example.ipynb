# %%
from sklearn.linear_model import LinearRegression
from sklearn import datasets

# %%
diabetes = datasets.load_diabetes()

# %%
# Sperate train and test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target, test_size=0.2, random_state=0)

# %%
# 1. Set up the model
model = LinearRegression()
# 2. Use fit
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
from modeleval import RegressionEvaluator

# %%
# Set up a regression evaluator object
eva = RegressionEvaluator()

# %%
eva.evaluate(model, X_test, y_test, plot=True, save=True, save_folder= "result/")
# Out:
# Evaluation Result
# ---Common Metrics---
# The mse is 3424.3167
# The mae is 46.1742
# The rmse is 58.5177
# The rmsle is 0.4084
# The r-square is 0.3322

# %%
# build another model
from sklearn.linear_model import Lasso

# %%
model2 = Lasso()

# %%
model2.fit(X_train, y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
eva.evaluate(model2, X_test, y_test)
# Out:
# Evaluation Result
# ---Common Metrics---
# The mse is 3787.8964
# The mae is 50.0898
# The rmse is 61.5459
# The rmsle is 0.4409
# The r-square is 0.2613

# %%
# find the model with maximum r square
bestmodel_r2 = eva.find_best_model([model, model2], X_test, y_test, "r2")
# Out:
# The model with maximum r-square (0.33222203269065176) is the 1 th model

# %%
# find the model with minimum rmse
bestmodel_rmse = eva.find_best_model([model, model2], X_test, y_test, "rmse")
# Out:
# The model with minimum rmse (58.51766133582009) is the 1 th model
